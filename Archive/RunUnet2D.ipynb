# %%
#!pip3 install -r requirements.txt

# %%
import sys
import os
sys.path.insert(0, os.getcwd()+"/Utils")
sys.path.insert(0, os.getcwd()+"/Models")

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
from skimage.io import imshow
import Unet2D
import mask_functions
import getNucleusSegmentationData
import ImageGeneration
from img_utils import generate_subimages
from keras.models import Model, load_model
import Augmentor
import shutil
import tensorflow as tf

# %%
from importlib import reload
reload(ImageGeneration)
reload(mask_functions)
reload(Unet2D)
# Out:
# <module 'Unet2D' from '/home/andrew/ImageSegmentation/Models/Unet2D.py'>

# %% [markdown]
# ### Tensorboard setup
# Use tensorboard to watch the progress. This is optional. If you want to see the results start tensorboard via command 'tensorboard --logdir=logs'. Expand and run the cell to enable tensorboard callback

# %%
import mask_functions
import ImageGeneration
from PIL import Image
from io import BytesIO
import base64
import keras
import numpy as np

def make_image(imagebg,imagefg):
    """
    Convert an numpy representation image to Image protobuf.
    Copied from https://github.com/lanpa/tensorboard-pytorch/
    """
    from PIL import Image
    height, width = imagebg.shape
    
    imagefg_mask = Image.fromarray(imagefg)
    imagebg = Image.fromarray(imagebg)

    
    red = Image.new('RGBA',imagebg.size,(255,0,0,125))
    
    
    image = Image.new("RGBA", imagebg.size)
    image.paste(imagebg)
    image.paste(red, (0, 0), imagefg_mask)

    
    import io
    output = io.BytesIO()
    image.save(output, format='PNG')
    image_string = output.getvalue()
    output.close()
    return tf.Summary.Image(height=height,
                         width=width,
                         colorspace=1,
                         encoded_image_string=image_string)
def colorize_model_output(model_inputs, img_array):
    full_color_dict = model_inputs['mask_color_dict']
    selected_keys = model_inputs['category_labels']
    color_dict = dict((i,full_color_dict[i]) for i in selected_keys if i in full_color_dict)
    ytrain = img_array.reshape(
        model_inputs['image_height'],
        model_inputs['image_width'],
        model_inputs['categories'])

    mask_dict = dict((i,ytrain[:,:,idx]==255) for idx,i in enumerate(selected_keys))

    color_img = mask_functions.colorize_mask_dict(mask_dict,color_dict)
    return color_img

def get_model_inputs():
    model_inputs = {
      "layer_count": 5,
      "starting_filter_count": 16,
      "convolution_dict": {
         "kernel_initializer": "he_normal",
         "alpha": 0.2,
         "kernel_size": (3, 3),
         "padding": "same",
        },
      "dropout_weight": 0.5,
      "pooling_dims": (2, 2),
      "stride_dims": (2, 2),
      "output_activation": "softmax",
      "image_height": 256,
      "image_width": 256,
      "input_channels": 1,
      "categories": 2,
      "mask_color_dict": mask_functions.original_color_dict(),
      "category_labels": ['background','nucleus'],
      "model_optimizer": "adam",
      "loss_function": "categorical_crossentropy",
      "validation_split": 0.1,
      "epochs": 50,
      "batch_size": 16,
      "filename": 'Unet2D-trained.h5',
      "stop_after": 10,
      "image_count": 10000,
      "image_directory": os.path.join(os.getcwd(), 'Training', 'Approved_Raw_Images'),
      "overwrite_images": False,
      "ground_truth_directory": os.path.join(os.getcwd(), 'Training', 'Approved'),
      "training_directory": os.path.join(os.getcwd(), 'Training', 'Approved_Raw_Images', 'output'),
      "test_split": 0.2
    }
    return model_inputs

class TensorBoardImage(keras.callbacks.Callback):
    def __init__(self, tag, ):
        self.histogram_freq=0
        self.write_graph=True
        self.write_images=True
        super().__init__() 
        self.tag = tag

        

  
    def on_epoch_end(self, epoch, logs={}):
        # Load image
        if epoch>1:
            params = get_model_inputs()
            filename = params['filename']
            directory_path = params['training_directory']
            filenames = os.listdir(directory_path)
            X_filenames = [os.path.join(directory_path,name) for name in filenames if name.startswith('Approved')]
            Y_filenames = [os.path.join(directory_path,name) for name in filenames if name.startswith('_groundtruth_')]

            X_filenames = X_filenames[0:99]
            Y_filenames = Y_filenames[0:99]
            X_files, Y_files = ImageGeneration.load_generated_images(X_filenames, Y_filenames, params)
            X_tr, X_te, Y_tr, Y_te = ImageGeneration.test_train_split(X_files, Y_files, params)
        
            best_model = load_model(params['filename'])
            predict = best_model.predict(X_tr)
            imbg = np.squeeze(X_tr[15])
            imfg = predict[15]
            imfg_mask = imfg.reshape(256,256,2)[:,:,1]
            imfg_mask_bool = ((imfg_mask>np.mean(imfg_mask))*255).astype('uint8')
            #imfg = predict[15].reshape(256,256,2)[:,:,1]
            #imfg = colorize_model_output(params,predict[19])

            image = make_image(imbg,imfg_mask_bool)
            summary = tf.Summary(value=[tf.Summary.Value(tag=self.tag, image=image)])
            writer = tf.summary.FileWriter('./logs')
            writer.add_summary(summary, epoch)
            writer.close()
        return

tbi_callback = TensorBoardImage('Image Example')

# %%
tb=TensorBoardImage('Image Example')
tb.on_epoch_end(6)

# %% [markdown]
# ## Global model variables are defined here

# %%
model_inputs = {
      "layer_count": 5,
      "starting_filter_count": 32,
      "convolution_dict": {
         "kernel_initializer": "he_normal",
         "alpha": 0.2,
         "kernel_size": (3, 3),
         "padding": "same",
        },
      "dropout_weight": 0,
      "pooling_dims": (2, 2),
      "stride_dims": (2, 2),
      "output_activation": "softmax",
      "image_height": 256,
      "image_width": 256,
      "input_channels": 1,
      "categories": 2,
      "category_labels": ['background','nucleus'],
      "mask_color_dict": mask_functions.original_color_dict(),
      "model_optimizer": "adam",
      "loss_function": 'categorical_crossentropy',
      "validation_split": 0.1,
      "epochs": 50,
      "batch_size": 16,
      "filename": 'Unet2D-trained.h5',
      "stop_after": 10,
      "image_count": 10000,
      "image_directory": os.path.join(os.getcwd(), 'Training', 'Approved_Raw_Images'),
      "overwrite_images": False,
      "ground_truth_directory": os.path.join(os.getcwd(), 'Training', 'Approved'),
      "training_directory": os.path.join(os.getcwd(), 'Training', 'Approved_Raw_Images', 'output'),
      "test_split": 0.2,
      "tb_callback": TensorBoardImage('Image Train 15v2'),
      "learning_rate": 0.004
    }

# %% [markdown]
# ## Get Training Image Data

# %% [markdown]
# Training data variables are defined with the rest of the model variables in model_inputs dict above
#
# **Training Data Variables**
#  - image_directory: Where approved training inputs are stored
#  - training_directory: temporary directory where augmented data is stored
#  - ground_truth_directory: directory where approved masks are stored
#  - image_count: Number of augmented images to generate
#  - test_split: % of images to be reserved for testing
#  - overwrite_images: Set to True to regenerate augmented data. If false, program attempts to reuse the generated data. Useful for troubleshooting.

# %% [markdown]
# ## Augment training dataset

# %%
X_train, X_test, Y_train, Y_test = ImageGeneration.get_data(model_inputs)
# Out:
# Executing Pipeline:   0%|          | 0/10000 [00:00<?, ? Samples/s]
# Initialised with 129 image(s) found.
# Output directory set to /home/andrew/ImageSegmentation/Training/Approved_Raw_Images/output.129 ground truth image(s) found.
# Processing <PIL.Image.Image image mode=L size=256x256 at 0x7F966C78EE48>: 100%|██████████| 10000/10000 [02:16<00:00, 73.31 Samples/s]
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-28-9452b90bcf67> in <module>
#       1
# ----> 2 X_train, X_test, Y_train, Y_test = ImageGeneration.get_data(model_inputs)
#
# ~/ImageSegmentation/Utils/ImageGeneration.py in get_data(model_inputs, pipeline)
#     126     X_images, Y_images = load_generated_images(X_filenames, Y_filenames, model_inputs)
#     127
# --> 128     X_train, X_test, Y_train, Y_test = test_train_split(X_images, Y_images, model_inputs)
#     129
#     130     return X_train, X_test, Y_train, Y_test
#
# ~/ImageSegmentation/Utils/ImageGeneration.py in test_train_split(X_images, Y_images, model_inputs)
#     113     X_train = X_images[train_numbers, :, :, :]
#     114     X_test  = X_images[test_numbers, :, :, :]
# --> 115     Y_train = Y_images[train_numbers, :, :]
#     116     Y_test  = Y_images[test_numbers, :, :]
#     117
#
# MemoryError:

# %% [markdown]
# ### Plot some images to qualitatively test our data augmentation and mask functions

# %%
def colorize_model_output(model_inputs, img_array):
    full_color_dict = model_inputs['mask_color_dict']
    selected_keys = model_inputs['category_labels']
    color_dict = dict((i,full_color_dict[i]) for i in selected_keys if i in full_color_dict)
    print(color_dict)
    ytrain = img_array.reshape(
        model_inputs['image_height'],
        model_inputs['image_width'],
        model_inputs['categories'])

    mask_dict = dict((i,ytrain[:,:,idx]==255) for idx,i in enumerate(selected_keys))

    color_img = mask_functions.colorize_mask_dict(mask_dict,color_dict,model_inputs['categories'])
    return color_img

# %%
import random
img_id = 15
#random.randint(0,X_test.shape[0]-1)
plt.subplot(1,2,1)
xtrain0 = imshow(np.squeeze(X_train[img_id]))
plt.title('X Train')

plt.subplot(1,2,2)
ytrain0 = Y_train[img_id].reshape(256,256,2)
imshow(np.squeeze(ytrain0)[:,:,1])
plt.title('Y Train')

img_id
# Out:
# 15

# %%
np.max(ytrain0)
# Out:
# 255

# %% [markdown]
# ## Define and Train Model

# %%
model = Unet2D.definemodel(model_inputs)

# %%
#model.summary()

# %%
model, results = Unet2D.trainmodel(X_train, Y_train, model, model_inputs)
# Out:
# Train on 7200 samples, validate on 800 samples
# Epoch 1/50
# 7200/7200 [==============================] - 142s 20ms/step - loss: 131.3748 - categorical_accuracy: 0.8397 - val_loss: 123.2047 - val_categorical_accuracy: 0.8482
#
# Epoch 00001: val_loss improved from inf to 123.20469, saving model to Unet2D-trained.h5
# Epoch 2/50
# 7200/7200 [==============================] - 134s 19ms/step - loss: 114.2591 - categorical_accuracy: 0.8689 - val_loss: 888.1872 - val_categorical_accuracy: 0.4837
#
# Epoch 00002: val_loss did not improve from 123.20469
# Epoch 3/50
# 7200/7200 [==============================] - 144s 20ms/step - loss: 44.4204 - categorical_accuracy: 0.9219 - val_loss: 41.7129 - val_categorical_accuracy: 0.9252
#
# Epoch 00003: val_loss improved from 123.20469 to 41.71286, saving model to Unet2D-trained.h5
# Epoch 4/50
# 7200/7200 [==============================] - 127s 18ms/step - loss: 36.6386 - categorical_accuracy: 0.9339 - val_loss: 48.6499 - val_categorical_accuracy: 0.9160
#
# Epoch 00004: val_loss did not improve from 41.71286
# Epoch 5/50
# 7200/7200 [==============================] - 127s 18ms/step - loss: 34.0196 - categorical_accuracy: 0.9374 - val_loss: 37.0062 - val_categorical_accuracy: 0.9321
#
# Epoch 00005: val_loss improved from 41.71286 to 37.00617, saving model to Unet2D-trained.h5
# Epoch 6/50
# 7200/7200 [==============================] - 141s 20ms/step - loss: 33.4708 - categorical_accuracy: 0.9386 - val_loss: 39.4222 - val_categorical_accuracy: 0.9291
#
# Epoch 00006: val_loss did not improve from 37.00617
# Epoch 7/50
# 7200/7200 [==============================] - 129s 18ms/step - loss: 31.8972 - categorical_accuracy: 0.9406 - val_loss: 36.6466 - val_categorical_accuracy: 0.9330
#
# Epoch 00007: val_loss improved from 37.00617 to 36.64663, saving model to Unet2D-trained.h5
# Epoch 8/50
# 7200/7200 [==============================] - 132s 18ms/step - loss: 31.2674 - categorical_accuracy: 0.9416 - val_loss: 62.9316 - val_categorical_accuracy: 0.8936
#
# Epoch 00008: val_loss did not improve from 36.64663
# Epoch 9/50
# 7200/7200 [==============================] - 130s 18ms/step - loss: 30.9173 - categorical_accuracy: 0.9421 - val_loss: 34.9081 - val_categorical_accuracy: 0.9350
#
# Epoch 00009: val_loss improved from 36.64663 to 34.90806, saving model to Unet2D-trained.h5
# Epoch 10/50
# 7200/7200 [==============================] - 130s 18ms/step - loss: 30.4211 - categorical_accuracy: 0.9428 - val_loss: 34.3534 - val_categorical_accuracy: 0.9359
#
# Epoch 00010: val_loss improved from 34.90806 to 34.35339, saving model to Unet2D-trained.h5
# Epoch 11/50
# 7200/7200 [==============================] - 130s 18ms/step - loss: 29.6812 - categorical_accuracy: 0.9439 - val_loss: 34.4141 - val_categorical_accuracy: 0.9351
#
# Epoch 00011: val_loss did not improve from 34.35339
# Epoch 12/50
# 7200/7200 [==============================] - 129s 18ms/step - loss: 29.0876 - categorical_accuracy: 0.9449 - val_loss: 33.8007 - val_categorical_accuracy: 0.9362
#
# Epoch 00012: val_loss improved from 34.35339 to 33.80074, saving model to Unet2D-trained.h5
# Epoch 13/50
# 7200/7200 [==============================] - 131s 18ms/step - loss: 28.7458 - categorical_accuracy: 0.9456 - val_loss: 120.3729 - val_categorical_accuracy: 0.8217
#
# Epoch 00013: val_loss did not improve from 33.80074
# Epoch 14/50
# 7200/7200 [==============================] - 130s 18ms/step - loss: 28.4209 - categorical_accuracy: 0.9462 - val_loss: 38.7770 - val_categorical_accuracy: 0.9306
#
# Epoch 00014: val_loss did not improve from 33.80074
# Epoch 15/50
# 7200/7200 [==============================] - 128s 18ms/step - loss: 28.1865 - categorical_accuracy: 0.9469 - val_loss: 34.4475 - val_categorical_accuracy: 0.9357
#
# Epoch 00015: val_loss did not improve from 33.80074
# Epoch 16/50
# 7200/7200 [==============================] - 133s 18ms/step - loss: 27.4044 - categorical_accuracy: 0.9485 - val_loss: 34.8348 - val_categorical_accuracy: 0.9340
#
# Epoch 00016: val_loss did not improve from 33.80074
# Epoch 17/50
# 7200/7200 [==============================] - 127s 18ms/step - loss: 26.7219 - categorical_accuracy: 0.9499 - val_loss: 34.2709 - val_categorical_accuracy: 0.9351
#
# Epoch 00017: val_loss did not improve from 33.80074
# Epoch 18/50
# 7200/7200 [==============================] - 128s 18ms/step - loss: 26.5930 - categorical_accuracy: 0.9508 - val_loss: 172.3826 - val_categorical_accuracy: 0.7433
#
# Epoch 00018: val_loss did not improve from 33.80074
# Epoch 19/50
# 7200/7200 [==============================] - 132s 18ms/step - loss: 27.5048 - categorical_accuracy: 0.9501 - val_loss: 77.9920 - val_categorical_accuracy: 0.8829
#
# Epoch 00019: val_loss did not improve from 33.80074
# Epoch 20/50
# 7200/7200 [==============================] - 129s 18ms/step - loss: 25.5303 - categorical_accuracy: 0.9539 - val_loss: 39.3427 - val_categorical_accuracy: 0.9309
#
# Epoch 00020: val_loss did not improve from 33.80074
# Epoch 21/50
# 7200/7200 [==============================] - 127s 18ms/step - loss: 24.3272 - categorical_accuracy: 0.9568 - val_loss: 36.8178 - val_categorical_accuracy: 0.9333
#
# Epoch 00021: val_loss did not improve from 33.80074
# Epoch 22/50
# 7200/7200 [==============================] - 128s 18ms/step - loss: 23.2230 - categorical_accuracy: 0.9596 - val_loss: 38.0247 - val_categorical_accuracy: 0.9342
#
# Epoch 00022: val_loss did not improve from 33.80074

# %% [markdown]
# ## Get Unlabeled Test Data

# %%
#help(generate_subimages)
#x_test = generate_subimages('Data/sem_image.PNG',128,20)

# %% [markdown]
# ## Make predictions on test data based on best model

# %%
best_model = load_model(model_inputs['filename'])
predict = best_model.predict(X_test)

# %%
num_predict = predict.shape[0]
predict = predict.reshape(num_predict,256,256,2)

# %%
### Generate predicted image for quantification

# %%
predict.shape
# Out:
# (200, 256, 256, 2)

# %%
idx = 15
plt.subplot(1,2,1)
imshow(np.squeeze(X_test[idx]))
plt.title('Noisy Image')
plt.subplot(1,2,2)
gray = predict[idx].reshape(256,256,2)
imshow(gray[:,:,1])
plt.title('Predicted')
#plt.subplot(1,3,3)
#imshow(np.squeeze(y_train[idx,:,:]))
#plt.title('Ground Truth')
fig = plt.gcf()
fig.set_size_inches(15, 5)

# %%
idx = 15
imshow(np.squeeze(X_test[idx]))
gray = predict[idx].reshape(256,256,2)
imshow(gray[:,:,1],alpha=0.6)
plt.title('ID ='+str(idx)+' Mask Overlay: Nucleus and Microvilli only')
#plt.subplot(1,3,3)
#imshow(np.squeeze(y_train[idx,:,:]))
#plt.title('Ground Truth')
fig = plt.gcf()
fig.set_size_inches(15, 5)

# %%
imshow(predict[idx][:,:,1]>np.mean(predict[idx][:,:,1]))
